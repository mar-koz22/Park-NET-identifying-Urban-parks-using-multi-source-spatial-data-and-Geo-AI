# %% [markdown]
# (still in progress)
# here I'm using a UNet with a pre-trained backbone

# %% [markdown]
# Loading numpy arrays with patches from Amsterdam, Dublin, Ghent, Manchester, Seattle and San Francisco. This patches have 3 bands - ndvi, landcover, ndbi. They were also filtered to have only patches that have at least 15% of parks. Based on them model is build - Unet with Resnet34 backbone

# %%
#install packages
#!pip install patchify
#!pip install segmentation_models

# %%
import os
import numpy as np

# %%
# Connecting to the Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# get the data from drive

# %%
#Amsterdam
image_array_amsterdam = np.load('location of Amsterdam image balanced chips')
park_array_amsterdam = np.load('location of Amsterdam parks balanced chips')

# %%
#dublin
image_array_dublin = np.load('location of Dublin image balanced chips')
park_array_dublin = np.load('location of Dublin parks balanced chips')

# %%
#ghent
image_array_ghent = np.load('location of Ghent image balanced chips')
park_array_ghent = np.load('location of Ghent parks balanced chips')

# %%
#Manchester
image_array_manchester = np.load('location of Manchester image balanced chips')
park_array_manchester = np.load('location of Manchester parks balanced chips')

# %%
#san francisco data
image_array_san_francisco = np.load('location of San Francisco image balanced chips')
park_array_san_francisco = np.load('location of San Francisco parks balanced chips')

# %%
#seattle data
image_array_seattle = np.load('location of seattle image balanced chips')
park_array_seattle = np.load('location of seattle parks balanced chips')

# %%
print(image_array_amsterdam.shape)
print(image_array_dublin.shape)
print(image_array_ghent.shape)
print(image_array_manchester.shape)
print(image_array_san_francisco.shape)
print(image_array_seattle.shape)
# Out:
# (475, 256, 256, 3)
# (691, 256, 256, 3)
# (320, 256, 256, 3)
# (579, 256, 256, 3)
# (525, 256, 256, 3)
# (290, 256, 256, 3)

# %% [markdown]
# merge into one numpy array

# %%
#merge into one numpy array
image_dataset = np.concatenate((image_array_amsterdam, image_array_dublin,  image_array_manchester, image_array_san_francisco, image_array_ghent,
                                image_array_seattle), axis=0)
park_dataset = np.concatenate((park_array_amsterdam, park_array_dublin,  park_array_manchester, park_array_san_francisco, park_array_ghent,
                                park_array_seattle), axis=0)

# %%
del image_array_amsterdam, image_array_dublin,  image_array_manchester, image_array_san_francisco, image_array_seattle , image_array_ghent,
del park_array_amsterdam, park_array_dublin,  park_array_manchester, park_array_san_francisco, park_array_seattle, park_array_ghent,

# %%
import random
import numpy as np
import matplotlib.pyplot as plt

# %%
# check whether the cropped images match

# generate random number
image_number = random.randint(0, len(image_dataset)-1)
plt.figure(figsize=(10, 5))

plt.subplot(121)
plt.imshow(image_dataset[image_number,:,:,0], cmap='RdYlGn')

# plot parks - white is park
plt.subplot(122)
plt.imshow(park_dataset[image_number,:,:,0], cmap='gray')
plt.show()

# %%
image_dataset[image_dataset > 1] = 1  # replace some wired values like 1.000001 with 1
print("Image data shape is: ", image_dataset.shape)
print("Park data shape is: ", park_dataset.shape)
print("Max pixel value in image is: ", image_dataset.max())
print("Min pixel value in image is: ", image_dataset.min())
print("Labels in the mask are : ", np.unique(park_dataset))
print("Number of park pixels: ", np.count_nonzero(park_dataset == 1))
print("Number of no-park pixels: ", np.count_nonzero(park_dataset == 0))
print("Percentage of park: ", np.count_nonzero(park_dataset == 1)/(np.count_nonzero(park_dataset == 1)+np.count_nonzero(park_dataset == 0)))
# Out:
# Image data shape is:  (2880, 256, 256, 3)
# Park data shape is:  (2880, 256, 256, 1)
# Max pixel value in image is:  1.0
# Min pixel value in image is:  0.0
# Labels in the mask are :  [0. 1.]
# Number of park pixels:  51776864
# Number of no-park pixels:  136966816
# Percentage of park:  0.27432369656032984

# %% [markdown]
# prepering data for modelling

# %%
from sklearn.model_selection import train_test_split
X_train_old, X_test_old, y_train, y_test = train_test_split(image_dataset, park_dataset, 
                                                    test_size = 0.15, random_state = 42) #changed the learning to 0.8 if more data

# %%
import cv2
import numpy as np

# %%
X_train_old.shape
# Out:
# (2448, 256, 256, 3)

# %%
y_train.shape
# Out:
# (2448, 256, 256, 1)

# %% [markdown]
# model building with a backbone

# %%
# preprocess input to fit model architecture
# %env SM_FRAMEWORK=tf.keras
import segmentation_models as sm
import keras
import tensorflow
from keras.layers import Input, Conv2D
from keras.models import Model

BACKBONE = 'resnet34'
preprocess_input = sm.get_preprocessing(BACKBONE) # get the preprocessing function
X_train = preprocess_input(X_train_old)
X_test = preprocess_input(X_test_old)
print(X_train.shape, X_test.shape)
# Out:
# env: SM_FRAMEWORK=tf.keras
# Segmentation Models: using `tf.keras` framework.
# (2448, 256, 256, 3) (432, 256, 256, 3)

# %%
# turn park_dataset into categorical
from tensorflow.keras.utils import to_categorical

# y_train
train_masks_cat = to_categorical(y_train, num_classes=2)
y_train = train_masks_cat.reshape((y_train.shape[0], y_train.shape[1], y_train.shape[2], 2))

# y_test
test_masks_cat = to_categorical(y_test, num_classes=2)
y_test = test_masks_cat.reshape((y_test.shape[0], y_test.shape[1], y_test.shape[2], 2))

print(y_train.shape, y_test.shape)
# Out:
# (2448, 256, 256, 2) (432, 256, 256, 2)

# %% [markdown]
# data augumentation

# %%
seed=24
from keras.preprocessing.image import ImageDataGenerator

img_data_gen_args = dict(rotation_range=90, width_shift_range=0.3, height_shift_range=0.3, shear_range=0.5, 
                         zoom_range=0.3, horizontal_flip=True, vertical_flip=True, fill_mode='reflect')

mask_data_gen_args = dict(rotation_range=90, width_shift_range=0.3, height_shift_range=0.3, shear_range=0.5, 
                         zoom_range=0.3, horizontal_flip=True, vertical_flip=True, fill_mode='reflect',
                         preprocessing_function = lambda x: np.where(x > 0, 1, 0).astype(x.dtype))

# %%
# set the batch size of image generator
batch_size= 8

# image generator (X_train and X_test)
image_data_generator = ImageDataGenerator(**img_data_gen_args)
image_data_generator.fit(X_train, augment=True, seed=seed)

image_generator = image_data_generator.flow(X_train, seed=seed, batch_size=batch_size)
valid_img_generator = image_data_generator.flow(X_test, seed=seed, batch_size=batch_size) 

# mask generator (y_train and y_test)
mask_data_generator = ImageDataGenerator(**mask_data_gen_args)
mask_data_generator.fit(y_train, augment=True, seed=seed)

mask_generator = mask_data_generator.flow(y_train, seed=seed, batch_size=batch_size)
valid_mask_generator = mask_data_generator.flow(y_test, seed=seed, batch_size=batch_size)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/image_data_generator.py:947: UserWarning: Expected input to be images (as Numpy array) following the data format convention "channels_last" (channels on axis 3), i.e. expected either 1, 3 or 4 channels on axis 3. However, it was passed an array with shape (2448, 256, 256, 2) (2 channels).
#   ' channels).')
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/numpy_array_iterator.py:136: UserWarning: NumpyArrayIterator is set to use the data format convention "channels_last" (channels on axis 3), i.e. expected either 1, 3, or 4 channels on axis 3. However, it was passed an array with shape (2448, 256, 256, 2) (2 channels).
#   str(self.x.shape[channels_axis]) + ' channels).')
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/numpy_array_iterator.py:136: UserWarning: NumpyArrayIterator is set to use the data format convention "channels_last" (channels on axis 3), i.e. expected either 1, 3, or 4 channels on axis 3. However, it was passed an array with shape (432, 256, 256, 2) (2 channels).
#   str(self.x.shape[channels_axis]) + ' channels).')

# %%
# put image generator and mask generator together
def my_image_mask_generator(image_generator, mask_generator):
    train_generator = zip(image_generator, mask_generator)
    for (img, mask) in train_generator:
        yield (img, mask)

train_generator = my_image_mask_generator(image_generator, mask_generator)
validation_generator = my_image_mask_generator(valid_img_generator, valid_mask_generator)

# %%
#check the augumentation 
x = image_generator.next()
y = mask_generator.next()
for i in range(0,1):
    plt.figure(figsize=(8, 4))
    image = x[i]
    mask = y[i]
    plt.subplot(121)
    plt.imshow(image[:,:,0])
    
    plt.subplot(122)
    plt.imshow(mask[:,:,1], cmap = 'gray')
    plt.show()

# %% [markdown]
# model set up

# %%
from tensorflow.keras.optimizers import Adam
import tensorflow as tf

# %%
# build model (U-Net with resnet34 backbone, pretrained on imagenet)
sm.set_framework('tf.keras')
sm.framework()

#define model
model = sm.Unet(backbone_name = 'resnet34', encoder_weights='imagenet', classes= 2, activation = 'sigmoid') 

# compile keras model with defined optimozer, loss and metrics
model.compile(optimizer=Adam(learning_rate = 1e-4), loss = sm.losses.binary_focal_loss, 
               metrics=['accuracy', sm.metrics.IOUScore(threshold=0.5), tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])
# #model.summary()
# Out:
# Downloading data from https://github.com/qubvel/classification_models/releases/download/0.0.1/resnet34_imagenet_1000_no_top.h5
# 85524480/85521592 [==============================] - 2s 0us/step
# 85532672/85521592 [==============================] - 2s 0us/step

# %%
# set hyperparameters - data augumentation
batch_size = 16
steps_per_epoch = len(X_train)//batch_size  # for generator, you need to specify the steps if using generator
validation_steps = len(X_test)//batch_size  # for generator
print(steps_per_epoch, validation_steps)
# Out:
# 153 27

# %%
# model training (with data augmentation)
history = model.fit(train_generator, batch_size=16, epochs=70,  steps_per_epoch = steps_per_epoch,
                     validation_steps = validation_steps, verbose=1, validation_data = validation_generator)
# Out:
# Epoch 1/70
# 153/153 [==============================] - 50s 219ms/step - loss: 0.0661 - accuracy: 0.7068 - iou_score: 0.3856 - precision: 0.7922 - recall: 0.5062 - val_loss: 0.0733 - val_accuracy: 0.7510 - val_iou_score: 0.3519 - val_precision: 0.7508 - val_recall: 0.6675
# Epoch 2/70
# 153/153 [==============================] - 31s 202ms/step - loss: 0.0408 - accuracy: 0.8389 - iou_score: 0.5357 - precision: 0.9220 - recall: 0.6606 - val_loss: 0.0796 - val_accuracy: 0.7496 - val_iou_score: 0.3748 - val_precision: 0.7496 - val_recall: 0.7262
# Epoch 3/70
# 153/153 [==============================] - 30s 199ms/step - loss: 0.0366 - accuracy: 0.8616 - iou_score: 0.6022 - precision: 0.9317 - recall: 0.7112 - val_loss: 0.0661 - val_accuracy: 0.7372 - val_iou_score: 0.3681 - val_precision: 0.7383 - val_recall: 0.7121
# Epoch 4/70
# 153/153 [==============================] - 30s 199ms/step - loss: 0.0332 - accuracy: 0.8772 - iou_score: 0.6482 - precision: 0.9408 - recall: 0.7468 - val_loss: 0.0811 - val_accuracy: 0.7410 - val_iou_score: 0.3692 - val_precision: 0.7486 - val_recall: 0.7002
# Epoch 5/70
# 153/153 [==============================] - 31s 200ms/step - loss: 0.0320 - accuracy: 0.8844 - iou_score: 0.6641 - precision: 0.9424 - recall: 0.7631 - val_loss: 0.0599 - val_accuracy: 0.7656 - val_iou_score: 0.3972 - val_precision: 0.8181 - val_recall: 0.6457
# Epoch 6/70
# 153/153 [==============================] - 31s 202ms/step - loss: 0.0314 - accuracy: 0.8868 - iou_score: 0.6751 - precision: 0.9453 - recall: 0.7678 - val_loss: 0.0468 - val_accuracy: 0.7967 - val_iou_score: 0.5289 - val_precision: 0.8814 - val_recall: 0.6414
# Epoch 7/70
# 153/153 [==============================] - 32s 211ms/step - loss: 0.0291 - accuracy: 0.8962 - iou_score: 0.6976 - precision: 0.9505 - recall: 0.7873 - val_loss: 0.0343 - val_accuracy: 0.8818 - val_iou_score: 0.6828 - val_precision: 0.9275 - val_recall: 0.7964
# Epoch 8/70
# 153/153 [==============================] - 32s 208ms/step - loss: 0.0285 - accuracy: 0.8997 - iou_score: 0.7094 - precision: 0.9511 - recall: 0.7969 - val_loss: 0.0284 - val_accuracy: 0.9044 - val_iou_score: 0.7178 - val_precision: 0.9473 - val_recall: 0.8217
# Epoch 9/70
# 153/153 [==============================] - 31s 205ms/step - loss: 0.0283 - accuracy: 0.8989 - iou_score: 0.7100 - precision: 0.9522 - recall: 0.7934 - val_loss: 0.0264 - val_accuracy: 0.9127 - val_iou_score: 0.7308 - val_precision: 0.9517 - val_recall: 0.8319
# Epoch 10/70
# 153/153 [==============================] - 31s 202ms/step - loss: 0.0268 - accuracy: 0.9067 - iou_score: 0.7257 - precision: 0.9547 - recall: 0.8115 - val_loss: 0.0282 - val_accuracy: 0.9084 - val_iou_score: 0.7139 - val_precision: 0.9530 - val_recall: 0.8111
# Epoch 11/70
# 153/153 [==============================] - 31s 205ms/step - loss: 0.0261 - accuracy: 0.9106 - iou_score: 0.7462 - precision: 0.9560 - recall: 0.8229 - val_loss: 0.0276 - val_accuracy: 0.9116 - val_iou_score: 0.7337 - val_precision: 0.9522 - val_recall: 0.8277
# Epoch 12/70
# 153/153 [==============================] - 31s 204ms/step - loss: 0.0263 - accuracy: 0.9104 - iou_score: 0.7372 - precision: 0.9555 - recall: 0.8216 - val_loss: 0.0257 - val_accuracy: 0.9187 - val_iou_score: 0.7584 - val_precision: 0.9610 - val_recall: 0.8329
# Epoch 13/70
# 153/153 [==============================] - 31s 201ms/step - loss: 0.0258 - accuracy: 0.9124 - iou_score: 0.7459 - precision: 0.9559 - recall: 0.8278 - val_loss: 0.0316 - val_accuracy: 0.9107 - val_iou_score: 0.7311 - val_precision: 0.9465 - val_recall: 0.8356
# Epoch 14/70
# 153/153 [==============================] - 31s 204ms/step - loss: 0.0254 - accuracy: 0.9130 - iou_score: 0.7498 - precision: 0.9568 - recall: 0.8281 - val_loss: 0.0270 - val_accuracy: 0.9130 - val_iou_score: 0.7488 - val_precision: 0.9532 - val_recall: 0.8326
# Epoch 15/70
# 153/153 [==============================] - 30s 199ms/step - loss: 0.0248 - accuracy: 0.9158 - iou_score: 0.7605 - precision: 0.9583 - recall: 0.8360 - val_loss: 0.0287 - val_accuracy: 0.9147 - val_iou_score: 0.7494 - val_precision: 0.9542 - val_recall: 0.8385
# Epoch 16/70
# 153/153 [==============================] - 30s 199ms/step - loss: 0.0235 - accuracy: 0.9198 - iou_score: 0.7626 - precision: 0.9610 - recall: 0.8418 - val_loss: 0.0250 - val_accuracy: 0.9213 - val_iou_score: 0.7565 - val_precision: 0.9565 - val_recall: 0.8534
# Epoch 17/70
# 153/153 [==============================] - 30s 199ms/step - loss: 0.0240 - accuracy: 0.9177 - iou_score: 0.7618 - precision: 0.9602 - recall: 0.8374 - val_loss: 0.0290 - val_accuracy: 0.9177 - val_iou_score: 0.7823 - val_precision: 0.9526 - val_recall: 0.8539
# Epoch 18/70
# 153/153 [==============================] - 30s 199ms/step - loss: 0.0231 - accuracy: 0.9216 - iou_score: 0.7748 - precision: 0.9617 - recall: 0.8473 - val_loss: 0.0261 - val_accuracy: 0.9204 - val_iou_score: 0.7594 - val_precision: 0.9581 - val_recall: 0.8450
# Epoch 19/70
# 153/153 [==============================] - 30s 199ms/step - loss: 0.0223 - accuracy: 0.9261 - iou_score: 0.7817 - precision: 0.9639 - recall: 0.8556 - val_loss: 0.0238 - val_accuracy: 0.9265 - val_iou_score: 0.7864 - val_precision: 0.9609 - val_recall: 0.8606
# Epoch 20/70
# 153/153 [==============================] - 31s 200ms/step - loss: 0.0226 - accuracy: 0.9244 - iou_score: 0.7830 - precision: 0.9629 - recall: 0.8532 - val_loss: 0.0244 - val_accuracy: 0.9240 - val_iou_score: 0.7860 - val_precision: 0.9592 - val_recall: 0.8643
# Epoch 21/70
# 153/153 [==============================] - 31s 206ms/step - loss: 0.0222 - accuracy: 0.9265 - iou_score: 0.7866 - precision: 0.9634 - recall: 0.8582 - val_loss: 0.0231 - val_accuracy: 0.9289 - val_iou_score: 0.7789 - val_precision: 0.9620 - val_recall: 0.8612
# Epoch 22/70
# 153/153 [==============================] - 32s 207ms/step - loss: 0.0213 - accuracy: 0.9280 - iou_score: 0.7926 - precision: 0.9656 - recall: 0.8602 - val_loss: 0.0240 - val_accuracy: 0.9280 - val_iou_score: 0.7943 - val_precision: 0.9601 - val_recall: 0.8712
# Epoch 23/70
# 153/153 [==============================] - 31s 202ms/step - loss: 0.0217 - accuracy: 0.9268 - iou_score: 0.7932 - precision: 0.9647 - recall: 0.8598 - val_loss: 0.0240 - val_accuracy: 0.9261 - val_iou_score: 0.7779 - val_precision: 0.9592 - val_recall: 0.8628
# Epoch 24/70
# 153/153 [==============================] - 31s 203ms/step - loss: 0.0209 - accuracy: 0.9299 - iou_score: 0.7955 - precision: 0.9659 - recall: 0.8653 - val_loss: 0.0234 - val_accuracy: 0.9332 - val_iou_score: 0.8102 - val_precision: 0.9638 - val_recall: 0.8787
# Epoch 25/70
# 153/153 [==============================] - 31s 202ms/step - loss: 0.0209 - accuracy: 0.9316 - iou_score: 0.8053 - precision: 0.9663 - recall: 0.8711 - val_loss: 0.0271 - val_accuracy: 0.9251 - val_iou_score: 0.7843 - val_precision: 0.9587 - val_recall: 0.8619
# Epoch 26/70
# 153/153 [==============================] - 30s 199ms/step - loss: 0.0215 - accuracy: 0.9284 - iou_score: 0.7893 - precision: 0.9649 - recall: 0.8617 - val_loss: 0.0238 - val_accuracy: 0.9262 - val_iou_score: 0.7935 - val_precision: 0.9616 - val_recall: 0.8624
# Epoch 27/70
# 153/153 [==============================] - 30s 198ms/step - loss: 0.0210 - accuracy: 0.9302 - iou_score: 0.7936 - precision: 0.9663 - recall: 0.8651 - val_loss: 0.0267 - val_accuracy: 0.9217 - val_iou_score: 0.7917 - val_precision: 0.9551 - val_recall: 0.8645
# Epoch 28/70
# 153/153 [==============================] - 31s 203ms/step - loss: 0.0205 - accuracy: 0.9308 - iou_score: 0.8011 - precision: 0.9669 - recall: 0.8665 - val_loss: 0.0237 - val_accuracy: 0.9292 - val_iou_score: 0.7904 - val_precision: 0.9607 - val_recall: 0.8680
# Epoch 29/70
# 153/153 [==============================] - 31s 201ms/step - loss: 0.0201 - accuracy: 0.9333 - iou_score: 0.8071 - precision: 0.9677 - recall: 0.8729 - val_loss: 0.0233 - val_accuracy: 0.9292 - val_iou_score: 0.8065 - val_precision: 0.9627 - val_recall: 0.8738
# Epoch 30/70
# 153/153 [==============================] - 31s 200ms/step - loss: 0.0201 - accuracy: 0.9342 - iou_score: 0.8100 - precision: 0.9679 - recall: 0.8756 - val_loss: 0.0226 - val_accuracy: 0.9310 - val_iou_score: 0.8049 - val_precision: 0.9639 - val_recall: 0.8707
# Epoch 31/70
# 153/153 [==============================] - 31s 202ms/step - loss: 0.0201 - accuracy: 0.9326 - iou_score: 0.8074 - precision: 0.9675 - recall: 0.8724 - val_loss: 0.0233 - val_accuracy: 0.9271 - val_iou_score: 0.7972 - val_precision: 0.9617 - val_recall: 0.8712
# Epoch 32/70
# 153/153 [==============================] - 31s 202ms/step - loss: 0.0191 - accuracy: 0.9355 - iou_score: 0.8139 - precision: 0.9695 - recall: 0.8769 - val_loss: 0.0222 - val_accuracy: 0.9353 - val_iou_score: 0.8182 - val_precision: 0.9642 - val_recall: 0.8867
# Epoch 33/70
# 153/153 [==============================] - 31s 203ms/step - loss: 0.0194 - accuracy: 0.9360 - iou_score: 0.8119 - precision: 0.9691 - recall: 0.8780 - val_loss: 0.0225 - val_accuracy: 0.9323 - val_iou_score: 0.8142 - val_precision: 0.9630 - val_recall: 0.8799
# Epoch 34/70
# 153/153 [==============================] - 31s 204ms/step - loss: 0.0206 - accuracy: 0.9324 - iou_score: 0.8080 - precision: 0.9665 - recall: 0.8734 - val_loss: 0.0226 - val_accuracy: 0.9331 - val_iou_score: 0.8067 - val_precision: 0.9610 - val_recall: 0.8842
# Epoch 35/70
# 153/153 [==============================] - 31s 203ms/step - loss: 0.0191 - accuracy: 0.9359 - iou_score: 0.8134 - precision: 0.9699 - recall: 0.8773 - val_loss: 0.0250 - val_accuracy: 0.9248 - val_iou_score: 0.8079 - val_precision: 0.9579 - val_recall: 0.8737
# Epoch 36/70
# 153/153 [==============================] - 31s 204ms/step - loss: 0.0194 - accuracy: 0.9365 - iou_score: 0.8191 - precision: 0.9693 - recall: 0.8803 - val_loss: 0.0232 - val_accuracy: 0.9327 - val_iou_score: 0.8087 - val_precision: 0.9630 - val_recall: 0.8816
# Epoch 37/70
# 153/153 [==============================] - 31s 202ms/step - loss: 0.0183 - accuracy: 0.9380 - iou_score: 0.8217 - precision: 0.9712 - recall: 0.8821 - val_loss: 0.0221 - val_accuracy: 0.9316 - val_iou_score: 0.8070 - val_precision: 0.9630 - val_recall: 0.8798
# Epoch 38/70
# 153/153 [==============================] - 31s 202ms/step - loss: 0.0187 - accuracy: 0.9379 - iou_score: 0.8232 - precision: 0.9704 - recall: 0.8831 - val_loss: 0.0251 - val_accuracy: 0.9298 - val_iou_score: 0.8213 - val_precision: 0.9618 - val_recall: 0.8794
# Epoch 39/70
# 153/153 [==============================] - 31s 203ms/step - loss: 0.0188 - accuracy: 0.9388 - iou_score: 0.8270 - precision: 0.9709 - recall: 0.8855 - val_loss: 0.0219 - val_accuracy: 0.9389 - val_iou_score: 0.8247 - val_precision: 0.9676 - val_recall: 0.8883
# Epoch 40/70
# 153/153 [==============================] - 31s 204ms/step - loss: 0.0180 - accuracy: 0.9407 - iou_score: 0.8286 - precision: 0.9716 - recall: 0.8885 - val_loss: 0.0247 - val_accuracy: 0.9336 - val_iou_score: 0.8105 - val_precision: 0.9607 - val_recall: 0.8870
# Epoch 41/70
# 153/153 [==============================] - 31s 202ms/step - loss: 0.0190 - accuracy: 0.9366 - iou_score: 0.8199 - precision: 0.9700 - recall: 0.8804 - val_loss: 0.0263 - val_accuracy: 0.9308 - val_iou_score: 0.8152 - val_precision: 0.9603 - val_recall: 0.8813
# Epoch 42/70
# 153/153 [==============================] - 31s 201ms/step - loss: 0.0182 - accuracy: 0.9404 - iou_score: 0.8268 - precision: 0.9718 - recall: 0.8871 - val_loss: 0.0237 - val_accuracy: 0.9320 - val_iou_score: 0.8217 - val_precision: 0.9606 - val_recall: 0.8866
# Epoch 43/70
# 153/153 [==============================] - 31s 202ms/step - loss: 0.0185 - accuracy: 0.9387 - iou_score: 0.8257 - precision: 0.9708 - recall: 0.8843 - val_loss: 0.0235 - val_accuracy: 0.9338 - val_iou_score: 0.8212 - val_precision: 0.9625 - val_recall: 0.8867
# Epoch 44/70
# 153/153 [==============================] - 31s 201ms/step - loss: 0.0179 - accuracy: 0.9408 - iou_score: 0.8336 - precision: 0.9716 - recall: 0.8897 - val_loss: 0.0210 - val_accuracy: 0.9383 - val_iou_score: 0.8266 - val_precision: 0.9666 - val_recall: 0.8920
# Epoch 45/70
# 153/153 [==============================] - 31s 201ms/step - loss: 0.0175 - accuracy: 0.9418 - iou_score: 0.8351 - precision: 0.9724 - recall: 0.8905 - val_loss: 0.0242 - val_accuracy: 0.9333 - val_iou_score: 0.8247 - val_precision: 0.9630 - val_recall: 0.8840
# Epoch 46/70
# 153/153 [==============================] - 31s 202ms/step - loss: 0.0179 - accuracy: 0.9422 - iou_score: 0.8377 - precision: 0.9726 - recall: 0.8919 - val_loss: 0.0221 - val_accuracy: 0.9340 - val_iou_score: 0.8356 - val_precision: 0.9653 - val_recall: 0.8882
# Epoch 47/70
# 153/153 [==============================] - 31s 201ms/step - loss: 0.0180 - accuracy: 0.9404 - iou_score: 0.8313 - precision: 0.9720 - recall: 0.8881 - val_loss: 0.0199 - val_accuracy: 0.9384 - val_iou_score: 0.8286 - val_precision: 0.9673 - val_recall: 0.8903
# Epoch 48/70
# 153/153 [==============================] - 31s 202ms/step - loss: 0.0169 - accuracy: 0.9441 - iou_score: 0.8417 - precision: 0.9738 - recall: 0.8958 - val_loss: 0.0211 - val_accuracy: 0.9394 - val_iou_score: 0.8268 - val_precision: 0.9656 - val_recall: 0.8956
# Epoch 49/70
# 153/153 [==============================] - 31s 202ms/step - loss: 0.0177 - accuracy: 0.9423 - iou_score: 0.8365 - precision: 0.9727 - recall: 0.8919 - val_loss: 0.0215 - val_accuracy: 0.9344 - val_iou_score: 0.8368 - val_precision: 0.9647 - val_recall: 0.8917
# Epoch 50/70
# 153/153 [==============================] - 31s 202ms/step - loss: 0.0175 - accuracy: 0.9423 - iou_score: 0.8381 - precision: 0.9727 - recall: 0.8923 - val_loss: 0.0247 - val_accuracy: 0.9286 - val_iou_score: 0.8269 - val_precision: 0.9613 - val_recall: 0.8822
# Epoch 51/70
# 153/153 [==============================] - 31s 203ms/step - loss: 0.0176 - accuracy: 0.9427 - iou_score: 0.8403 - precision: 0.9729 - recall: 0.8937 - val_loss: 0.0202 - val_accuracy: 0.9395 - val_iou_score: 0.8382 - val_precision: 0.9675 - val_recall: 0.8951
# Epoch 52/70
# 153/153 [==============================] - 31s 201ms/step - loss: 0.0166 - accuracy: 0.9451 - iou_score: 0.8414 - precision: 0.9741 - recall: 0.8977 - val_loss: 0.0218 - val_accuracy: 0.9319 - val_iou_score: 0.8352 - val_precision: 0.9643 - val_recall: 0.8876
# Epoch 53/70
# 153/153 [==============================] - 31s 202ms/step - loss: 0.0176 - accuracy: 0.9419 - iou_score: 0.8370 - precision: 0.9725 - recall: 0.8919 - val_loss: 0.0228 - val_accuracy: 0.9353 - val_iou_score: 0.8377 - val_precision: 0.9636 - val_recall: 0.8952
# Epoch 54/70
# 153/153 [==============================] - 31s 202ms/step - loss: 0.0180 - accuracy: 0.9408 - iou_score: 0.8302 - precision: 0.9717 - recall: 0.8883 - val_loss: 0.0207 - val_accuracy: 0.9380 - val_iou_score: 0.8356 - val_precision: 0.9655 - val_recall: 0.8969
# Epoch 55/70
# 153/153 [==============================] - 31s 202ms/step - loss: 0.0168 - accuracy: 0.9452 - iou_score: 0.8469 - precision: 0.9741 - recall: 0.8992 - val_loss: 0.0198 - val_accuracy: 0.9435 - val_iou_score: 0.8283 - val_precision: 0.9673 - val_recall: 0.9001
# Epoch 56/70
# 153/153 [==============================] - 31s 203ms/step - loss: 0.0167 - accuracy: 0.9451 - iou_score: 0.8419 - precision: 0.9743 - recall: 0.8973 - val_loss: 0.0201 - val_accuracy: 0.9411 - val_iou_score: 0.8318 - val_precision: 0.9691 - val_recall: 0.8957
# Epoch 57/70
# 153/153 [==============================] - 31s 202ms/step - loss: 0.0159 - accuracy: 0.9478 - iou_score: 0.8531 - precision: 0.9757 - recall: 0.9037 - val_loss: 0.0195 - val_accuracy: 0.9429 - val_iou_score: 0.8453 - val_precision: 0.9689 - val_recall: 0.9014
# Epoch 58/70
# 153/153 [==============================] - 30s 199ms/step - loss: 0.0160 - accuracy: 0.9464 - iou_score: 0.8489 - precision: 0.9752 - recall: 0.9007 - val_loss: 0.0187 - val_accuracy: 0.9435 - val_iou_score: 0.8356 - val_precision: 0.9702 - val_recall: 0.9013
# Epoch 59/70
# 153/153 [==============================] - 30s 199ms/step - loss: 0.0155 - accuracy: 0.9488 - iou_score: 0.8546 - precision: 0.9763 - recall: 0.9050 - val_loss: 0.0216 - val_accuracy: 0.9395 - val_iou_score: 0.8450 - val_precision: 0.9659 - val_recall: 0.8979
# Epoch 60/70
# 153/153 [==============================] - 31s 201ms/step - loss: 0.0164 - accuracy: 0.9464 - iou_score: 0.8466 - precision: 0.9749 - recall: 0.8998 - val_loss: 0.0228 - val_accuracy: 0.9402 - val_iou_score: 0.8357 - val_precision: 0.9651 - val_recall: 0.8995
# Epoch 61/70
# 153/153 [==============================] - 30s 199ms/step - loss: 0.0160 - accuracy: 0.9470 - iou_score: 0.8509 - precision: 0.9755 - recall: 0.9015 - val_loss: 0.0186 - val_accuracy: 0.9432 - val_iou_score: 0.8435 - val_precision: 0.9715 - val_recall: 0.8989
# Epoch 62/70
# 153/153 [==============================] - 30s 200ms/step - loss: 0.0155 - accuracy: 0.9485 - iou_score: 0.8547 - precision: 0.9763 - recall: 0.9051 - val_loss: 0.0213 - val_accuracy: 0.9438 - val_iou_score: 0.8415 - val_precision: 0.9674 - val_recall: 0.9043
# Epoch 63/70
# 153/153 [==============================] - 31s 202ms/step - loss: 0.0164 - accuracy: 0.9465 - iou_score: 0.8511 - precision: 0.9750 - recall: 0.9012 - val_loss: 0.0213 - val_accuracy: 0.9398 - val_iou_score: 0.8501 - val_precision: 0.9674 - val_recall: 0.9002
# Epoch 64/70
# 153/153 [==============================] - 31s 201ms/step - loss: 0.0163 - accuracy: 0.9460 - iou_score: 0.8456 - precision: 0.9751 - recall: 0.8989 - val_loss: 0.0224 - val_accuracy: 0.9376 - val_iou_score: 0.8488 - val_precision: 0.9655 - val_recall: 0.8981
# Epoch 65/70
# 153/153 [==============================] - 30s 200ms/step - loss: 0.0161 - accuracy: 0.9476 - iou_score: 0.8510 - precision: 0.9753 - recall: 0.9031 - val_loss: 0.0208 - val_accuracy: 0.9398 - val_iou_score: 0.8394 - val_precision: 0.9662 - val_recall: 0.9006
# Epoch 66/70
# 153/153 [==============================] - 30s 198ms/step - loss: 0.0156 - accuracy: 0.9484 - iou_score: 0.8542 - precision: 0.9761 - recall: 0.9048 - val_loss: 0.0192 - val_accuracy: 0.9414 - val_iou_score: 0.8538 - val_precision: 0.9701 - val_recall: 0.9030
# Epoch 67/70
# 153/153 [==============================] - 31s 200ms/step - loss: 0.0153 - accuracy: 0.9493 - iou_score: 0.8561 - precision: 0.9764 - recall: 0.9064 - val_loss: 0.0183 - val_accuracy: 0.9452 - val_iou_score: 0.8546 - val_precision: 0.9703 - val_recall: 0.9071
# Epoch 68/70
# 153/153 [==============================] - 30s 198ms/step - loss: 0.0163 - accuracy: 0.9476 - iou_score: 0.8554 - precision: 0.9755 - recall: 0.9050 - val_loss: 0.0225 - val_accuracy: 0.9392 - val_iou_score: 0.8463 - val_precision: 0.9653 - val_recall: 0.8969
# Epoch 69/70
# 153/153 [==============================] - 30s 199ms/step - loss: 0.0147 - accuracy: 0.9515 - iou_score: 0.8639 - precision: 0.9775 - recall: 0.9117 - val_loss: 0.0207 - val_accuracy: 0.9428 - val_iou_score: 0.8431 - val_precision: 0.9677 - val_recall: 0.9059
# Epoch 70/70
# 153/153 [==============================] - 30s 199ms/step - loss: 0.0152 - accuracy: 0.9499 - iou_score: 0.8605 - precision: 0.9769 - recall: 0.9085 - val_loss: 0.0208 - val_accuracy: 0.9437 - val_iou_score: 0.8544 - val_precision: 0.9686 - val_recall: 0.9066

# %%
#save model

from tensorflow import keras
model.save('location to save the model') #save model to drive

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Metrics 'accuracy', sm.metrics.IOUScore(threshold=0.5), tf.keras.metrics.Precision(), tf.keras.metrics.Recall()]
loss, acc, IoU, precision, recall = model.evaluate(X_test, y_test, verbose = 0)

print("Loss is ", loss)
print("Accuracy is ", acc)
print("IoU is ", IoU)
print("Precision is", precision)
print("Recall is", recall)
# Out:
# Loss is  0.013686315156519413
# Accuracy is  0.9558470845222473
# IoU is  0.8878619074821472
# Precision is 0.9691907167434692
# Recall is 0.9341250061988831

# %%
#how many pixels are predicted to be parks
y_pred=model.predict(X_test)
y_pred.mean()
# Out:
# 0.46846956

# %% [markdown]
# plot ground truth + predicted

# %%
test_img_number = random.randint(0, len(X_test))
test_img = X_test[test_img_number]
ground_truth=y_test[test_img_number]
test_img_input=np.expand_dims(test_img, 0)

test_img_input1 = preprocess_input(test_img_input)

test_pred1 = model.predict(test_img_input1)
test_prediction1 = np.argmax(test_pred1, axis=3)[0,:,:]

print(test_prediction1.shape)

plt.figure(figsize=(16, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[:,:,0])

plt.subplot(232)
plt.title('Groud truth')
plt.imshow(ground_truth[:,:,1], cmap='gray')

plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(test_prediction1, cmap='gray')

plt.show()
# Out:
# (256, 256)

# %% [markdown]
# test on Philedelphia in different script
